# %%
# from gensim.corpora import WikiCorpus

# input_file = "../../../data/zhwiki-20231001-pages-articles-multistream.xml.bz2"
# wiki = WikiCorpus(input_file, dictionary={})

# i = 0

# for text in wiki.get_texts():
#     # str_line = bytes.join(b' ', text).decode()
#     str_line = text
#     print(str_line)

#     i = i + 1
#     if i == 5:
#         break

# %%
# file_path_zh = 'C:/Users/yanghe/Desktop/datasets/wikipedia/zhwiki-20231001-pages-articles-multistream.xml'
# file_path_kk = 'C:/Users/yanghe/Desktop/datasets/wikipedia/kkwiki-20231001-pages-articles-multistream.xml'
# wikidata_path = 'C:/Users/yanghe/Desktop/datasets/wikipedia/wikidatawiki-20231001-pages-articles-multistream1.xml-p1p441397'
# #

# %%
# with open(wikidata_path, 'r', encoding='utf-8') as f:
#     for _ in range(10000):
#         print(f.readline())

# %%
# with open(file_path_kk, 'r', encoding='utf-8') as f:
#     for _ in range(10000):
#         line = f.readline()
#         print(line)

# '''
#     <title>Батыс Қазақстан облысы</title>

#     <ns>0</ns>

#     <id>1658</id>
# '''

# %%
# # 获取kk文件长度
# with open(file_path_kk, 'r', encoding='utf-8') as f:
#     print(len(f.readlines()))
# #     # 212577298

# %%
# 获取zh文件长度
# with open(file_path_zh, 'r', encoding='utf-8') as f:
#     print(len(f.readlines()))
#     # 212577298

# %%
# # 查找对应的 id

# title_lable = '<title>Қытай</title>'
# # 

# with open(file_path_kk, 'r', encoding='utf-8') as f:

#     for i in range(212577298):
#         text = f.readline().strip()
#         if title_lable == text:
#             print(i)
#             break

# %%
# with open(file_path_kk, 'r', encoding='utf-8') as f:

#     for i in range(3000):
#         line = f.readline()
#         if i == 2591:
#             print(line)
#             print(f.readline())
#             print(f.readline())

#             break

# %%
# # 查找对应的 id

# id_lable = '<id>1034</id>'

# with open(file_path_zh, 'r', encoding='utf-8') as f:

#     for i in range(212577298):
#         text = f.readline().strip()
#         if id_lable == text:
#             print(text)
#             print(i)
#             break

# %%
# with open(file_path_zh, 'r', encoding='utf-8') as f:

#     for i in range(212577298):
#         line = f.readline()
#         if i == 128304:
#             print(line)
#             # print(f.readline())
#             # print(f.readline())

#             break

# %%
# with open(file_path_zh, 'r', encoding='utf-8') as f:
#     for i in range(11100):
#         line = f.readline()
#         if i >= 11000:
#             print(line)
#     # lines = f.readlines()
#     # print(len(lines))

# print('--------------------------------------------')

# with open(file_path_kk, 'r', encoding='utf-8') as f:
#     for i in range(11100):
#         line = f.readline()
#         if i >= 11000:
#             print(line)

# %%
# file_path_kk_pages = "C:/Users/yanghe/Desktop/datasets/wikipedia/kkwiki-20231001-pages-articles-multistream.xml"

# with open(file_path_kk_pages, 'r', encoding='utf-8') as f:
#     for _ in range(100):
#         print(f.readline())

# %%
# import pathlib
# # file_path_zh_pages = pathlib.Path("C:\Users\yanghe\Desktop\datasets\wikipedia\zhwiki-20231001-pages-articles-multistream.xml")
# file_path_zh_pages = pathlib.Path("C:/Users/yanghe/Desktop/datasets/wikipedia").joinpath("zhwiki-20231001-pages-articles-multistream.xml")

# with open(file_path_zh_pages, 'r', encoding='utf-8') as f:
#     for _ in range(10000):
#         print(f.readline())

# %%
# file_path_zh_pages_1 = "C:/Users/yanghe/Desktop/datasets/wikipedia/zhwiki-20231001-pages-articles1.xml-p1p187712"

# with open(file_path_zh_pages_1, 'r', encoding='utf-8') as f:
#     for _ in range(10000):
#         print(f.readline())

# %%
# file_path_zh_pages_2 = "C:/Users/yanghe/Desktop/datasets/wikipedia/zhwiki-20231001-pages-articles1.xml-p1p187712"

# str1 = '<title>'
# str2 = '<ns>0</ns>'
# str3 = '<id>78</id>'

# with open(file_path_zh_pages_2, 'r', encoding='utf-8') as f:
#     # for _ in range(len(f.readlines())):
#     #     text1 = f.readline()

#     #     if str1 in text1:
#     #         text2 = f.readline().strip()
#     #         if str2 == text2.strip():
#     #             text3 = f.readline().strip()
#     #             if str3 == text3:
#     #                 print(text1)
#     #             else:
#     #                 break
#     #         else:
#     #             break
#     #     else:
#     #         break
#     for i in range(10000):
#         line = f.readline()
#         if i == 9319:
#             print(line)
#             break
#         # text3 = f.readline().strip()
#         # print(text3)
#         # if str3 == text3:
#         #     print(i)
#         #     break
